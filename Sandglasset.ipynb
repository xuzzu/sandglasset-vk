# %%
import math
import tensorflow

class Sandglasset(object):    
    def __init__(self, modelPath = "sandglasset.npy", in_channels, out_channels, kernel_size, length, hidden_channels=128, num_layers=1,
             bidirectional=True, num_heads=8, cycle_amount=6, speakers=2):
        super(Sandglasset, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.length = length
        self.hidden_channels = hidden_channels
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_heads = num_heads
        self.cycle_amount = cycle_amount
        self.speakers = speakers
        self.Encoder = createEncoder(out_channels=self.in_channels,
                               kernel_size=self.kernel_size)
        self.Decoder = createDecoder(in_channels=self.in_channels,
                               kernel_size=self.kernel_size)
        self.SandglassetBlock = creaeteSandglassetBlock(in_channels)
        
    def makeConfig(self):
        config = {absin_channels: 256,
                        out_channels: 64,
                        kernel_size: 8,
                        length: 256,
                        hidden_channels: 128,
                        num_layers: 1,
                        bidirectional: True,
                        num_heads: 8,
                        cycle_amount: 6,
                        speakers: 2}
        return config
    
    def positionalEncoding(self, position, model)
        angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                              np.arange(d_model)[np.newaxis, :], model)
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)
    
#     def createEncoder(self):
        
    
    def createDecoder(self):
        # Decoder
        # Standard config kernel_size=16, stride=8
        conv1dtranspose4_1 = tf.keras.layers.Conv1DTranspose(kernel_size=16, stride=8, padding='same', filters=1)(X)
    
    def createSandglassetBlock(self, in_channels):
        # Local RNN
        embed1_1 = tf.keras.layers.Embedding(X, num_distinct_words, embedding_output_dims, input_length=max_sequence_length)(X)
        lstm1_1 = LSTM(embed1_1)(embed1_1)
        dense_activation1_1 = tf.keras.layers.Dense(1, activation='sigmoid')(lstm1_1)

        # Downsampling
        conv1d2_1 = tf.keras.layers.Conv1D(filters=1, padding='same', stride=1)(dense_activation1_1)

        # Globally attentive
        pos_enc3_1 = positionalEncoding(0, num_channels)(conv1d2_1)
        mult_head_attention3_2 = tf.keras.layers.MultiHeadAttention(dropout=0.1, num_heads=8, key_dim=num_channels)(pos_enc3_1)

        # Transpose + Upsampling
        conv1dtranspose4_1 = tf.keras.layers.Conv1DTranspose(stride=1, padding='same', filters=1)(mult_head_attention3_2)   


if __name__ == "__main__":
    x = torch.rand(1, 32000)
    model = Sandglasset(in_channels=256,
                        out_channels=64,
                        kernel_size=8,
                        length=256,
                        hidden_channels=128,
                        num_layers=1,
                        bidirectional=True,
                        num_heads=8,
                        cycle_amount=6,
                        speakers=2)
    y = model(x)
